# %%
import pandas as pd 
import os, sys
import os.path as osp   
import numpy as np
import matplotlib.pyplot as plt
sys.path.append("../scripts")

# %%
test_dict = pd.read_pickle(osp.join("..", "test_folder", "GraphSage.dat"))

# %%
id   = test_dict["id"]
reco = test_dict['reco']
truth = test_dict['targets']

# %%
from test_script import azi_zen_from_units

# %%
reco_azi, reco_zen = azi_zen_from_units(reco[:, :3])
reco_en            = reco[:, 3]
true_azi, true_zen = azi_zen_from_units(truth[:, :3])
true_en            = truth[:, 3]

# %%
csv_dict = {
    "event_no": id, 
    "zenith": true_zen,
    "zenith_pred": reco_zen,
    "energy_log10": true_en,
    "energy_log10_pred":  reco_en
}
df = pd.DataFrame(csv_dict)
df.to_csv("/groups/hep/johannbs/common_predictions/predict_files/GraphSageSTDpenal.csv")

# %%
plt.hist(reco_zen, bins = 100, histtype= "step");
plt.hist(true_zen, bins = 100, histtype = "step");
# plt.hist(true_zen, bins = 100);

# %%
plt.hist(reco_zen - true_zen, bins = 100, histtype = "step");

# %%
plt.hist2d(reco_zen, true_zen, bins = 100);

# %%
plt.hist2d(reco_en, true_en, bins = 100);

# %%
x[1].shape
# Out:
# (7, 5)

# %%
pd.DataFrame(x[0])

# %%
x, y = pd.read_pickle(os.path.join("..", "data", "features", "MuonsTest", "train50000.dat"))
plt.hist(y[:, 2], bins = 100);

# %%
y[:, 1:]
# Out:
# array([[4.434384  , 0.40617896],
#        [1.39347674, 0.64952375],
#        [0.93319101, 0.35560721],
#        ...,
#        [5.96767565, 1.02769969],
#        [3.05269532, 1.13985414],
#        [3.38052106, 1.05212987]])

# %%
import matplotlib.pyplot as plt 

np.concatenate(x)
# Out:
# array([[-0.80177513,  0.32778989,  0.36618868,  0.04853649,  1.03245861],
#        [-0.80177513,  0.32778989,  0.33195904,  0.03668025,  0.50835111],
#        [-0.80177513,  0.32778989,  0.29772942,  0.09373842,  0.23806267],
#        ...,
#        [-0.62053174,  0.81627012,  0.09174827, -0.22341608,  0.37896459],
#        [-0.62053174,  0.81627012,  0.12597791, -0.27343461,  0.50835111],
#        [-0.62053174,  0.81627012,  0.12597791, -0.30307521,  0.50835111]])

# %%
y
# Out:
# array([[7.13101600e+06, 1.51179985e+00, 1.17941677e+00],
#        [7.13110100e+06, 5.37759901e+00, 1.84913419e+00],
#        [7.13127100e+06, 6.17094016e+00, 2.17087827e+00],
#        ...,
#        [1.17104750e+08, 4.38546582e+00, 9.22474453e-01],
#        [1.17104752e+08, 1.58638274e+00, 9.57550670e-01],
#        [1.17104758e+08, 4.63404827e+00, 8.88264142e-01]])

# %%
xs = np.concatenate(x)
plt.hist(xs[:100000, :].T)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-f110d07f2593> in <module>
#       1 xs = np.concatenate(x)
# ----> 2 plt.hist(xs[:100000, :].T)
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2683         orientation='vertical', rwidth=None, log=False, color=None,
#    2684         label=None, stacked=False, *, data=None, **kwargs):
# -> 2685     return gca().hist(
#    2686         x, bins=bins, range=range, density=density, weights=weights,
#    2687         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6716                 else:
#    6717                     height = m
# -> 6718                 bars = _barfunc(bins[:-1]+boffset, height, width,
#    6719                                 align='center', log=log,
#    6720                                 color=c, **{bottom_kwarg: bottom})
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2405
#    2406         if orientation == 'vertical':
# -> 2407             self._process_unit_info(xdata=x, ydata=height, kwargs=kwargs)
#    2408             if log:
#    2409                 self.set_yscale('log', nonpositive='clip')
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/matplotlib/axes/_base.py in _process_unit_info(self, xdata, ydata, kwargs)
#    2188
#    2189         kwargs = _process_single_axis(xdata, self.xaxis, 'xunits', kwargs)
# -> 2190         kwargs = _process_single_axis(ydata, self.yaxis, 'yunits', kwargs)
#    2191         return kwargs
#    2192
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/matplotlib/axes/_base.py in _process_single_axis(data, axis, unit_name, kwargs)
#    2170                 # We only need to update if there is nothing set yet.
#    2171                 if not axis.have_units():
# -> 2172                     axis.update_units(data)
#    2173
#    2174             # Check for units in the kwargs, and if present update axis
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/matplotlib/axis.py in update_units(self, data)
#    1458         if *data* is registered for unit conversion.
#    1459         """
# -> 1460         converter = munits.registry.get_converter(data)
#    1461         if converter is None:
#    1462             return False
#
# KeyboardInterrupt:

# %%
plt.hist(np.concatenate(x)[:10000, 4])

# %%
from scripts.he

# %%
from helper_functions import angles_to_units

# %%
import tensorflow as tf

# %%
tf.math.reduce_euclidean_norm(angles_to_units(tf.cast(y, tf.float32)[:, 1:]), axis = 1
# Out:
# <tf.Tensor: shape=(50000, 3), dtype=float32, numpy=
# array([[ 0.05450379,  0.92277545,  0.38146403],
#        [ 0.59346974, -0.7565063 , -0.27475786],
#        [ 0.8200959 , -0.09244053, -0.56471   ],
#        ...,
#        [-0.25597286, -0.75487983,  0.60384965],
#        [-0.01274581,  0.817685  ,  0.57552475],
#        [-0.06072835, -0.773598  ,  0.63075995]], dtype=float32)>

# %%
import matplotlib.pyplot as plt

# %%
import sqlite3 2"

# %%
path = "/groups/hep/pcs557/databases/dev_lvl7_mu_nu_e_classification_v003/data/dev_lvl7_mu_nu_e_classification_v003_unscaled.db"
with sqlite3.connect(path) as conn:
